# %% [markdown]
# # MLG: Lab 5 (Part 2)
#
# ## Exercise 3: Self-organized representation of a collection of images
#
# ### Dataset information
#
# The Wang image database is a database of images grouped by class. In this dataset, we downloaded only the 1000 images. You can download them on this website: http://wang.ist.psu.edu/docs/home.shtml more precisely at this address: http://wang.ist.psu.edu/~jwang/test1.tar
#
# For each class we have 100 corresponding images:
# - 0-100: Africans
# - 100-200: Beaches
# - 200-300: Monuments
# - etc...
#
# All the images in this dataset are 250x166 pixels or 166x250 pixels.

# %%
import sys
# !{sys.executable} -m pip install -U scikit-learn scipy matplotlib
# Out:
# Requirement already up-to-date: scikit-learn in c:\users\nortalle\appdata\local\programs\python\python37-32\lib\site-packages (0.21.0)
# Requirement already up-to-date: scipy in c:\users\nortalle\appdata\local\programs\python\python37-32\lib\site-packages (1.2.1)
# Requirement already up-to-date: matplotlib in c:\users\nortalle\appdata\local\programs\python\python37-32\lib\site-packages (3.0.3)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in c:\users\nortalle\appdata\local\programs\python\python37-32\lib\site-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\nortalle\appdata\local\programs\python\python37-32\lib\site-packages (from scikit-learn) (0.13.2)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in c:\users\nortalle\appdata\local\programs\python\python37-32\lib\site-packages (from matplotlib) (2.3.1)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in c:\users\nortalle\appdata\local\programs\python\python37-32\lib\site-packages (from matplotlib) (1.0.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in c:\users\nortalle\appdata\local\programs\python\python37-32\lib\site-packages (from matplotlib) (2.8.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in c:\users\nortalle\appdata\local\programs\python\python37-32\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied, skipping upgrade: setuptools in c:\users\nortalle\appdata\local\programs\python\python37-32\lib\site-packages (from kiwisolver>=1.0.1->matplotlib) (40.8.0)
# Requirement already satisfied, skipping upgrade: six>=1.5 in c:\users\nortalle\appdata\local\programs\python\python37-32\lib\site-packages (from python-dateutil>=2.1->matplotlib) (1.12.0)
# You are using pip version 19.0.3, however version 19.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import sys
# !{sys.executable} -m pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in c:\users\nortalle\appdata\local\programs\python\python37-32\lib\site-packages (0.15.0)
# Requirement already satisfied: imageio>=2.0.1 in c:\users\nortalle\appdata\local\programs\python\python37-32\lib\site-packages (from scikit-image) (2.5.0)
# Requirement already satisfied: PyWavelets>=0.4.0 in c:\users\nortalle\appdata\local\programs\python\python37-32\lib\site-packages (from scikit-image) (1.0.3)
# Requirement already satisfied: pillow>=4.3.0 in c:\users\nortalle\appdata\local\programs\python\python37-32\lib\site-packages (from scikit-image) (6.0.0)
# Requirement already satisfied: networkx>=2.0 in c:\users\nortalle\appdata\local\programs\python\python37-32\lib\site-packages (from scikit-image) (2.3)
# Requirement already satisfied: numpy in c:\users\nortalle\appdata\local\programs\python\python37-32\lib\site-packages (from imageio>=2.0.1->scikit-image) (1.16.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\nortalle\appdata\local\programs\python\python37-32\lib\site-packages (from networkx>=2.0->scikit-image) (4.3.2)
# You are using pip version 19.0.3, however version 19.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import numpy as np
import matplotlib.pylab as pl
import KohonenUtils
import WangImageUtilities
# %matplotlib inline

# %%
extractor = WangImageUtilities.ImageFeatureExtractor('Wang_Data')
# Here we load images from 300-399 and from 500-599
# extractor.load_images(list_indices=list(np.arange(300, 400)) + list(np.arange(500, 600)) + list(np.arange(700, 800)))
extractor.load_images(list_indices=list(np.arange(100,200)) + list(np.arange(600,700)) + list(np.arange(900, 1000)))
# extractor.load_images(list_indices=list(np.arange(0,100)) + list(np.arange(200,300)) + list(np.arange(800, 900)))
# Out:
# 300 images loaded!

# %% [markdown]
# ### Dataset Visualization

# %%
pl.figure(figsize=(10, 20))
pl.subplot(121)
pl.imshow(extractor.images[2])
pl.axis('off')
pl.subplot(122)
pl.imshow(extractor.images[101])
_ = pl.axis('off')

# %% [markdown]
# ### Clustering with SOM

# %%
method = 3
if method == 1:
    histograms = extractor.extract_histogram()
elif method == 2:
    histograms = extractor.extract_hue_histogram()
elif method == 3:
    histograms = extractor.extract_color_histogram()
else:
    print('Implement your own method for extracting features if you like!')

np.shape(histograms)
# Out:
# (300, 30)

# %%
rows_cols = [10]
methods = [1, 2, 3]
n_iterations = [50]

for method in methods:
    for row_col in rows_cols:
        for n_iter in n_iterations:
            
            if method == 1:
                histograms = extractor.extract_histogram()
            elif method == 2:
                histograms = extractor.extract_hue_histogram()
            elif method == 3:
                histograms = extractor.extract_color_histogram()
            else:
                print('Implement your own method for extracting features if you like!')

            kmap = KohonenUtils.KohonenMap(side_rows=row_col,
                                           side_cols=row_col,
                                           size_vector=histograms.shape[1])

            learning_rate = KohonenUtils.ExponentialTimeseries(1, 0.05, n_iter*histograms.shape[0])
            neighborhood_size = KohonenUtils.ExponentialTimeseries(2./3 * kmap._map.shape[1], 1, n_iter*histograms.shape[0])

            names = []
            for index in extractor.image_indices:
                names.append(str(index))

            kmap.train(histograms, names, n_iter, learning_rate, neighborhood_size)

            kmap.plot_umatrix(plot_empty=True, plot_names=True)

            # Writes a 'som.html' file
            # You can visualize the results and click on a neuron to see other images assigned to this neuron
            extractor.to_html('3_som_method_{}_row_col_{}_iter_{}.html'.format(method,row_col,n_iter), kmap)
# Out:
# C:\Users\Nortalle\Desktop\BA6\MLG\Labos\Pratical_Work_3\kohonen.py:430: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return self._neighborhood_mask[z] ** (1.0 / sigma / sigma)
# C:\Users\Nortalle\Desktop\BA6\MLG\Labos\Pratical_Work_3\kohonen.py:430: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return self._neighborhood_mask[z] ** (1.0 / sigma / sigma)
# C:\Users\Nortalle\Desktop\BA6\MLG\Labos\Pratical_Work_3\kohonen.py:430: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return self._neighborhood_mask[z] ** (1.0 / sigma / sigma)

# %% [markdown]
# To simplify analysis, we can write the images to HTML. This is easier to see and analyze.

# %% [markdown]
# <h3>REPORT (date of submission: 23.5 before 23:55)</h3>
#
# 1. Explain the three different methods we provided for extracting features. What do you understand about them (input, output), how do they work ?</p>
#
# 2. Try the SOM with several (minimum 3) different sets of images (always 100 images per class and at least two classes). You can change the size of the Self-Organizing Map as well as its parameters.
# <ul>
# <li> Note that we provided three methods for extracting features: for at least one of the test you do try with all three methods and compare the results.
# <li> Include for each experiment an U-Matrix (with images - print screen of html)) that you find interesting. Explain why you find it interesting (what are the input images, with which features you trained your Self-Organizing Map, with which parameters, and how it is reflected in the results)...
# </ul>
# </p>
